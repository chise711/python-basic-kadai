# %%
#forの場合
planet_list = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]
for planet in planet_list:
   print(planet)

#whileの場合
planet_list = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]
i = 0
while i < len(planet_list):
  print(planet_list[i])
  i +=1
  if i == 9:
    break
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
